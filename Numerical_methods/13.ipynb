# %% [markdown]
# # Úloha 13: Výpočet Hilbertovy transformace
#
# *Využití FFT pro výpočet konvoluce*
#
# Hilbertova transformace funkce $f(x)$ je definována jako integrál ve smyslu **hlavní hodnoty**:
#
# $$
# g(y) = \operatorname{v.p.} \int \frac{f(x)}{y - x}\, dx.
# $$
#
# Napište program počítající Hilbertovu transformaci předem zadané funkce. Využijte toho, že Hilbertova transformace má tvar **konvoluce** s distribucí $\operatorname{v.p.}\,1/x$, jejíž Fourierovu transformaci známe (můžete si ji spočítat integrací v komplexní rovině, když si uvědomíte, že)
#
# $$
# \operatorname{v.p.}\,\frac{1}{x} = \operatorname{Re}\,\frac{1}{x + i\varepsilon}.
# $$
#
# Nejdříve otestujte program pro přímou a zpětnou transformaci tím, že pomocí Fourierovy transformace spočítáte derivaci nějaké funkce a následně spočtete Hilbertovu transformaci funkce
#
# $$
# \theta(x)\, x e^{-x},
# $$
#
# kde $\theta(x)$ je **Heavisideova skoková funkce**.
#
# Testujte závislost výsledků na volbě:
# - vzorkovací hustoty,
# - intervalu, na němž provádíte transformaci.

# %%
import numpy as np

interval = 10
n = 2**8
dx = interval/n

def naive_four(f,x):

# np.fft.fft()
# Out:
# [ 0.          0.12566371  0.25132741 ... -0.37699112 -0.25132741
#  -0.12566371]
